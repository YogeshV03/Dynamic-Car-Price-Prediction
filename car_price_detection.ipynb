# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv("/content/drive/MyDrive/DS_AND_ML/carpricetraining.csv")

# %%
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   object
#  8   Engine             5983 non-null   object
#  9   Power              5983 non-null   object
#  10  Seats              5977 non-null   float64
#  11  New_Price          824 non-null    object
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 611.4+ KB

# %%
df.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price
# count  6019.000000       6.019000e+03  5977.000000  6019.000000
# mean   2013.358199       5.873838e+04     5.278735     9.479468
# std       3.269742       9.126884e+04     0.808840    11.187917
# min    1998.000000       1.710000e+02     0.000000     0.440000
# 25%    2011.000000       3.400000e+04     5.000000     3.500000
# 50%    2014.000000       5.300000e+04     5.000000     5.640000
# 75%    2016.000000       7.300000e+04     5.000000     9.950000
# max    2019.000000       6.500000e+06    10.000000   160.000000

# %%
df.drop(['New_Price'],axis=1,inplace=True)

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
def converted_data(x):
    splited_data=x.split()
    splited_data=float(splited_data[0])
    return splited_data

# %%
x=['Mileage','Engine','Power']

# %%
def converted_data2(x):
    try:
        return(float(str(x).split()[0]))
    except:
        pass

# %%
coverted_data3=lambda:float(x.split()[0])

# %%
for col in x:
    df[col] = df[col].apply(lambda a : converted_data2(a))

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  Price
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0   1.75
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0  12.50
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0   4.50
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0   6.00
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0  17.74

# %%
df.isnull().sum()
# Out:
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage                2
# Engine                36
# Power                143
# Seats                 42
# Price                  0
# dtype: int64

# %%
mil_mean = df['Mileage'].mean()

# %%
pow_mean = df['Power'].mean()

# %%
eng_mean = df['Engine'].mean()

# %%
seat_mode = df['Seats'].mode()

# %%
df['Mileage'].fillna(value=mil_mean, inplace=True)

# %%
df['Power'].fillna(value=pow_mean, inplace=True)
df['Engine'].fillna(value=eng_mean, inplace=True)
df['Seats'].fillna(value=seat_mode[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6019 non-null   float64
#  8   Engine             6019 non-null   float64
#  9   Power              6019 non-null   float64
#  10  Seats              6019 non-null   float64
#  11  Price              6019 non-null   float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 564.4+ KB

# %%
seat_mode
# Out:
# 0    5.0
# Name: Seats, dtype: float64

# %%
cities_in_table=df['Location'].unique()

# %%
cities_in_data={}
i = 0
for city in  list(cities_in_table):
    cities_in_data[city] = i
    i += 1

# %%
cities_in_data
# Out:
# {'Mumbai': 0,
#  'Pune': 1,
#  'Chennai': 2,
#  'Coimbatore': 3,
#  'Hyderabad': 4,
#  'Jaipur': 5,
#  'Kochi': 6,
#  'Kolkata': 7,
#  'Delhi': 8,
#  'Bangalore': 9,
#  'Ahmedabad': 10}

# %%
list_of_cities = list(cities_in_table)

# %%
list_of_cities
# Out:
# ['Mumbai',
#  'Pune',
#  'Chennai',
#  'Coimbatore',
#  'Hyderabad',
#  'Jaipur',
#  'Kochi',
#  'Kolkata',
#  'Delhi',
#  'Bangalore',
#  'Ahmedabad']

# %%
df['Location'] = df['Location'].apply(lambda x : list_of_cities.index(x))

# %%
df.head()
# Out:
#                                Name  Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG         0  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option         1  2015              41000
# 2                      Honda Jazz V         2  2011              46000
# 3                 Maruti Ertiga VDI         2  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic         3  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  Price
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0   1.75
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0  12.50
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0   4.50
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0   6.00
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0  17.74

# %%
fuel_types=df['Fuel_Type'].unique()

# %%
list_of_fuel_types=list(fuel_types)

# %%
list_of_fuel_types
# Out:
# ['CNG', 'Diesel', 'Petrol', 'LPG', 'Electric']

# %%
df['Fuel_Type']=df['Fuel_Type'].apply(lambda x: list_of_fuel_types.index(x))

# %%
df.head()
# Out:
#                                Name  Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG         0  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option         1  2015              41000
# 2                      Honda Jazz V         2  2011              46000
# 3                 Maruti Ertiga VDI         2  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic         3  2013              40670
#
#    Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  Price
# 0          0       Manual      First    26.60   998.0   58.16    5.0   1.75
# 1          1       Manual      First    19.67  1582.0  126.20    5.0  12.50
# 2          2       Manual      First    18.20  1199.0   88.70    5.0   4.50
# 3          1       Manual      First    20.77  1248.0   88.76    7.0   6.00
# 4          1    Automatic     Second    15.20  1968.0  140.80    5.0  17.74

# %%
owner_type=df['Owner_Type'].unique()
list_of_owner_type=list(owner_type)
list_of_owner_type
# Out:
# ['First', 'Second', 'Fourth & Above', 'Third']

# %%
df['Owner_Type']=df['Owner_Type'].apply(lambda x: list_of_owner_type.index(x))

# %%
df.head()
# Out:
#                                Name  Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG         0  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option         1  2015              41000
# 2                      Honda Jazz V         2  2011              46000
# 3                 Maruti Ertiga VDI         2  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic         3  2013              40670
#
#    Fuel_Type Transmission  Owner_Type  Mileage  Engine   Power  Seats  Price
# 0          0       Manual           0    26.60   998.0   58.16    5.0   1.75
# 1          1       Manual           0    19.67  1582.0  126.20    5.0  12.50
# 2          2       Manual           0    18.20  1199.0   88.70    5.0   4.50
# 3          1       Manual           0    20.77  1248.0   88.76    7.0   6.00
# 4          1    Automatic           1    15.20  1968.0  140.80    5.0  17.74

# %%
transmission_type=df['Transmission'].unique()
list_of_transmission_type=list(transmission_type)
list_of_transmission_type
# Out:
# ['Manual', 'Automatic']

# %%
df['Transmission']=df['Transmission'].apply(lambda x: list_of_transmission_type.index(x))

# %%
df.head()
# Out:
#                                Name  Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG         0  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option         1  2015              41000
# 2                      Honda Jazz V         2  2011              46000
# 3                 Maruti Ertiga VDI         2  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic         3  2013              40670
#
#    Fuel_Type  Transmission  Owner_Type  Mileage  Engine   Power  Seats  Price
# 0          0             0           0    26.60   998.0   58.16    5.0   1.75
# 1          1             0           0    19.67  1582.0  126.20    5.0  12.50
# 2          2             0           0    18.20  1199.0   88.70    5.0   4.50
# 3          1             0           0    20.77  1248.0   88.76    7.0   6.00
# 4          1             1           1    15.20  1968.0  140.80    5.0  17.74

# %%
seats_type=df['Seats'].unique()
list_of_seats_type=list(seats_type)
list_of_seats_type
# Out:
# [5.0, 7.0, 8.0, 4.0, 6.0, 2.0, 10.0, 9.0, 0.0]

# %%
df['Seats']=df['Seats'].apply(lambda x: list_of_seats_type.index(x))

# %%
df.head()
# Out:
#                                Name  Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG         0  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option         1  2015              41000
# 2                      Honda Jazz V         2  2011              46000
# 3                 Maruti Ertiga VDI         2  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic         3  2013              40670
#
#    Fuel_Type  Transmission  Owner_Type  Mileage  Engine   Power  Seats  Price
# 0          0             0           0    26.60   998.0   58.16      0   1.75
# 1          1             0           0    19.67  1582.0  126.20      0  12.50
# 2          2             0           0    18.20  1199.0   88.70      0   4.50
# 3          1             0           0    20.77  1248.0   88.76      1   6.00
# 4          1             1           1    15.20  1968.0  140.80      0  17.74

# %%
df.drop(['Name'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0         0  2010              72000          0             0           0
# 1         1  2015              41000          1             0           0
# 2         2  2011              46000          2             0           0
# 3         2  2012              87000          1             0           0
# 4         3  2013              40670          1             1           1
#
#    Mileage  Engine   Power  Seats  Price
# 0    26.60   998.0   58.16      0   1.75
# 1    19.67  1582.0  126.20      0  12.50
# 2    18.20  1199.0   88.70      0   4.50
# 3    20.77  1248.0   88.76      1   6.00
# 4    15.20  1968.0  140.80      0  17.74

# %%
kms_min = df['Kilometers_Driven'].min()
kms_max = df['Kilometers_Driven'].max()

def scaler(x, min_, max_):
    return (x-min_)/(max_-min_)

# %%
df['Kilometers_Driven'] = df['Kilometers_Driven'].apply(lambda x: scaler(x, kms_min,kms_max))

# %%
df.head()
# Out:
#    Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0         0  2010           0.011051          0             0           0
# 1         1  2015           0.006282          1             0           0
# 2         2  2011           0.007051          2             0           0
# 3         2  2012           0.013359          1             0           0
# 4         3  2013           0.006231          1             1           1
#
#    Mileage  Engine   Power  Seats  Price
# 0    26.60   998.0   58.16      0   1.75
# 1    19.67  1582.0  126.20      0  12.50
# 2    18.20  1199.0   88.70      0   4.50
# 3    20.77  1248.0   88.76      1   6.00
# 4    15.20  1968.0  140.80      0  17.74

# %%
e_min = df['Engine'].min()
e_max = df['Engine'].max()

def scaler(x, min_, max_):
    return (x-min_)/(max_-min_)

# %%
df['Engine'] = df['Engine'].apply(lambda x: scaler(x, e_min,e_max))

# %%
m_min = df['Mileage'].min()
m_max = df['Mileage'].max()

def scaler(x, min_, max_):
    return (x-min_)/(max_-min_)

# %%
df['Mileage'] = df['Mileage'].apply(lambda x: scaler(x, m_min,m_max))

# %%
p_min = df['Power'].min()
p_max = df['Power'].max()

def scaler(x, min_, max_):
    return (x-min_)/(max_-min_)

# %%
df['Power'] = df['Power'].apply(lambda x: scaler(x, p_min,p_max))

# %%
df.head()
# Out:
#    Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0         0  2010           0.011051          0             0           0
# 1         1  2015           0.006282          1             0           0
# 2         2  2011           0.007051          2             0           0
# 3         2  2012           0.013359          1             0           0
# 4         3  2013           0.006231          1             1           1
#
#     Mileage    Engine     Power  Seats  Price
# 0  0.793083  0.156261  0.045569      0   1.75
# 1  0.586464  0.254809  0.174971      0  12.50
# 2  0.542636  0.190179  0.103652      0   4.50
# 3  0.619261  0.198448  0.103766      1   6.00
# 4  0.453190  0.319946  0.202739      0  17.74

# %%
y_min = df['Year'].min()
y_max = df['Year'].max()

def scaler(x, min_, max_):
    return (x-min_)/(max_-min_)

# %%
df['Year'] = df['Year'].apply(lambda x: scaler(x, y_min,y_max))

# %%
df.head()
# Out:
#    Location      Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0         0  0.571429           0.011051          0             0           0
# 1         1  0.809524           0.006282          1             0           0
# 2         2  0.619048           0.007051          2             0           0
# 3         2  0.666667           0.013359          1             0           0
# 4         3  0.714286           0.006231          1             1           1
#
#     Mileage    Engine     Power  Seats  Price
# 0  0.793083  0.156261  0.045569      0   1.75
# 1  0.586464  0.254809  0.174971      0  12.50
# 2  0.542636  0.190179  0.103652      0   4.50
# 3  0.619261  0.198448  0.103766      1   6.00
# 4  0.453190  0.319946  0.202739      0  17.74

# %%
df
# Out:
#       Location      Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0            0  0.571429           0.011051          0             0
# 1            1  0.809524           0.006282          1             0
# 2            2  0.619048           0.007051          2             0
# 3            2  0.666667           0.013359          1             0
# 4            3  0.714286           0.006231          1             1
# ...        ...       ...                ...        ...           ...
# 6014         8  0.761905           0.004184          1             0
# 6015         5  0.809524           0.015359          1             0
# 6016         5  0.666667           0.008435          1             0
# 6017         7  0.714286           0.007051          2             0
# 6018         4  0.619048           0.007205          1             0
#
#       Owner_Type   Mileage    Engine     Power  Seats  Price
# 0              0  0.793083  0.156261  0.045569      0   1.75
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['Kilometers_Driven']]
Y = df['Price']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(Y_test, y_pred)
# Out:
# 236.36049717984764

# %%
Y = df['Price']
X = df[['fLocation', 'Year', 'Kilometers_Driven','Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power','Seats']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-b5640e5037fc> in <cell line: 2>()
#       1 Y = df['Price']
# ----> 2 X = df[['fLocation', 'Year', 'Kilometers_Driven','Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power','Seats']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
regressor.fit(X_train, Y_train)

# %%
y_pred = regressor.predict(X_test)

# %%
mean_error=mean_squared_error(Y_test, y_pred)

# %%
X_train.shape

# %%
X_test.shape

# %%
# !pip install LinearRegression

# %%
from LinearRegression import LinearRegression

# %%
import joblib

# %%
joblib.dump(regressor,"lr.pkl")
# Out:
# ['lr.pkl']

# %%
Joblib_LR = joblib.load("lr.pkl")
# Validate the R sqaured value of test data, it should be same of the original model

# %%
input_kilometers=float(input("enter the kilometer:"))
input_flocation=float(input("enter the flocation:"))
input_Year=float(input("enter the year:"))
input_fuel_type=float(input("enter the fuel type:"))
input_transmission=float(input("enter the transmission:"))
input_owner_type=float(input("enter the owner type:"))
input_mileage=float(input("enter the mileage:"))
input_engine=float(input("enter the engine:"))
input_power=float(input("enter the power:"))
input_seats=float(input("enter the seats:"))

# %%
input_pricing=([[
input_flocation,
input_Year,
input_kilometers,
input_fuel_type,
input_transmission,
input_owner_type,
input_mileage,
input_engine,
input_power,
input_seats]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-f4866590b784> in <cell line: 2>()
#       1 input_pricing=([[
# ----> 2 input_flocation,
#       3 input_Year,
#       4 input_kilometers,
#       5 input_fuel_type,
#
# NameError: name 'input_flocation' is not defined

# %%
df_pred=Joblib_LR.predict(input_pricing)

# %%
df_pred

# %%
import numpy as np

# %% [markdown]
# mean_df_pred=np.mean(df_pred)

# %%
actual_price=mean_df_pred*100000

# %%
actual_price

# %%
price_range=([actual_price+mean_error,actual_price-mean_error])

# %%
price_range

# %%
type(price_range)
